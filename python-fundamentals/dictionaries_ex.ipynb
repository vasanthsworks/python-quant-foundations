# %% [markdown]
#  6-1. Person: Use a dictionary to store information about a person you know.
#  Store their first name, last name, age, and the city in which they live. You
# should have keys such as first_name, last_name, age, and city. Print each
# piece of information stored in your dictionary.
#     6-2. Favorite Numbers: Use a dictionary to store people’s favorite numbers.
# Think of five names, and use them as keys in your dictionary. Think of a favorite
# number for each person, and store each as a value in your dictionary. Print
# each person’s name and their favorite number. For even more fun, poll a few
# friends and get some actual data for your program.

# %%
#6.1
person_1={"first_name":"vasanth","last_name":"s","age":19,"city":"chennai"}
print("name of the person is:",person_1["first_name"]+" "+person_1["last_name"])
print("age of the person is:",person_1["age"],"\n"
    "city they live in:",person_1["city"])
# Out:
# name of the person is: vasanth s
# age of the person is: 19
# city they live in: chennai

# %%
#6.2
people_ph_num={
    "sarah":2267879810,
    "victor":6671345692,
    "bobby":9933545892,
    "marie":7732148457,
    "noah":9961378294
}
print("phone numbers of people in dataset are:","\n"
      ,"sarah:",people_ph_num["sarah"],"\n",
      "vicotr:",people_ph_num["victor"],"\n",
      "bobby:",people_ph_num["bobby"],"\n",
      "marie:",people_ph_num["marie"],"\n",
      "noah:",people_ph_num["noah"])
# Out:
# phone numbers of people in dataset are:
#  sarah: 2267879810
#  vicotr: 6671345692
#  bobby: 9933545892
#  marie: 7732148457
#  noah: 9961378294

# %% [markdown]
# 6.5 Rivers: Make a dictionary containing three major rivers and the continent
# each river runs through. One key-value pair might be 'nile': 'egypt'.
# •	 Use a loop to print a sentence about each river, such as The Nile runs
# through Egypt.
# •	 Use a loop to print the name of each river included in the dictionary.
# •	 Use a loop to print the name of each country included in the dictionary.
# 6-6. Polling: Use the code in favorite_languages.py (page 104).
# •	 Make a list of people who should take the favorite languages poll. Include
# some names that are already in the dictionary and some that are not.
# •	 Loop through the list of people who should take the poll. If they have
# already taken the poll, print a message thanking them for responding.
# If they have not yet taken the poll, print a message inviting them to take
# the poll.

# %%
#6.5
rivers_0={"NILE":"AFRICA","AMAZON":"SOUTH AMERICA","YANGTZE":"ASIA"}
for name,place in rivers_0.items():
    print("the river that flows in ",place,"is:",name)
# Out:
# the river that flows in  AFRICA is: NILE
# the river that flows in  SOUTH AMERICA is: AMAZON
# the river that flows in  ASIA is: YANGTZE

# %%
#6.6
favorite_languages = {
     'jen': 'python',
 'sarah': 'c',
 'edward': 'ruby',
 'phil': 'python',
 }
list_people=["jen","sarah","edward","phil","vincent","romeo"]
for name in list_people:
    if name in favorite_languages.keys():
        print("thank you for taking the poll", name)
    else:
        print("need to take the poll",name)
# Out:
# thank you for taking the poll jen
# thank you for taking the poll sarah
# thank you for taking the poll edward
# thank you for taking the poll phil
# need to take the poll vincent
# need to take the poll romeo

# %% [markdown]
# ### Exercise 6-7: People
# Start with the program you wrote for Exercise 6-1.
# - Make two new dictionaries representing different people, and store all three dictionaries in a list called `people`.
# - Loop through your list of people.
# - As you loop through the list, print everything you know about each person.

# %%
person1 = {
    'first_name': 'jen',
    'last_name': 'doe',
    'age': 25,
    'city': 'new york'
}
person2 = {
    'first_name': 'sarah',
    'last_name': 'lee',
    'age': 30,
    'city': 'chicago'
}
person3 = {
    'first_name': 'edward',
    'last_name': 'smith',
    'age': 40,
    'city': 'san francisco'
}
people = [person1, person2, person3]
for person in people:
    print("\nPerson info:")
    for key, value in person.items():
        print(f"{key.title()}: {value}")
# Out:
# Person info:
# First_Name: jen
# Last_Name: doe
# Age: 25
# City: new york
#
# Person info:
# First_Name: sarah
# Last_Name: lee
# Age: 30
# City: chicago
#
# Person info:
# First_Name: edward
# Last_Name: smith
# Age: 40
# City: san francisco
